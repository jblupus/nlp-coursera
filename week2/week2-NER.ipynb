# %% [markdown]
# # Recognize named entities on Twitter with LSTMs
#
# In this assignment, you will use a recurrent neural network to solve Named Entity Recognition (NER) problem. NER is a common task in natural language processing systems. It serves for extraction such entities from the text as persons, organizations, locations, etc. In this task you will experiment to recognize named entities from Twitter.
#
# For example, we want to extract persons' and organizations' names from the text. Than for the input text:
#
#     Ian Goodfellow works for Google Brain
#
# a NER model needs to provide the following sequence of tags:
#
#     B-PER I-PER    O     O   B-ORG  I-ORG
#
# Where *B-* and *I-* prefixes stand for the beginning and inside of the entity, while *O* stands for out of tag or no tag. Markup with the prefix scheme is called *BIO markup*. This markup is introduced for distinguishing of consequent entities with similar types.
#
# A solution of the task will be based on neural networks, particularly, on Bi-Directional Long Short-Term Memory Networks (Bi-LSTMs).
#
# ### Libraries
#
# For this task you will need the following libraries:
#  - [Tensorflow](https://www.tensorflow.org) — an open-source software library for Machine Intelligence.
#  - [Numpy](http://www.numpy.org) — a package for scientific computing.
#
# If you have never worked with Tensorflow, you would probably need to read some tutorials during your work on this assignment, e.g. [this one](https://www.tensorflow.org/tutorials/recurrent) could be a good starting point.

# %% [markdown]
# ### Data
#
# The following cell will download all data required for this assignment into the folder `week2/data`.

# %%
import sys
sys.path.append("..")
from common.download_utils import download_week2_resources

download_week2_resources()
# Out:
# File data/train.txt is already downloaded.
# File data/validation.txt is already downloaded.
# File data/test.txt is already downloaded.

# %% [markdown]
# ### Load the Twitter Named Entity Recognition corpus
#
# We will work with a corpus, which contains tweets with NE tags. Every line of a file contains a pair of a token (word/punctuation symbol) and a tag, separated by a whitespace. Different tweets are separated by an empty line.
#
# The function *read_data* reads a corpus from the *file_path* and returns two lists: one with tokens and one with the corresponding tags. You need to complete this function by adding a code, which will replace a user's nickname to `<USR>` token and any URL to `<URL>` token. You could think that a URL and a nickname are just strings which start with *http://* or *https://* in case of URLs and a *@* symbol for nicknames.

# %%
import re

def replace_usr(text):
    return re.sub(r'@[0-9a-zA-Z\_\.\-]+', '<USR>', text)

def replace_url(text):
    #return re.sub(r'http(s){0,1}:[0-9a-zA-Z\/\.\-\_\$#@:\?!=\+\(\)\[\]\{\}\\]+', '<URL>', text)
    return re.sub(r'((\S+\.)+\S+)\/\S+', '<URL>', text)

def read_data(file_path):
    tokens = []
    tags = []
    
    tweet_tokens = []
    tweet_tags = []
    for line in open(file_path, encoding='utf-8'):
        line = line.strip()
        if not line:
            if tweet_tokens:
                tokens.append(tweet_tokens)
                tags.append(tweet_tags)
            tweet_tokens = []
            tweet_tags = []
        else:
            token, tag = line.split()
            # Replace all urls with <URL> token
            # Replace all users with <USR> token
            
            token = replace_url(token)
            token = replace_usr(token)
            tweet_tokens.append(token)
            tweet_tags.append(tag)
            
    return tokens, tags

# %% [markdown]
# And now we can load three separate parts of the dataset:
#  - *train* data for training the model;
#  - *validation* data for evaluation and hyperparameters tuning;
#  - *test* data for final evaluation of the model.

# %%
train_tokens, train_tags = read_data('data/train.txt')
validation_tokens, validation_tags = read_data('data/validation.txt')
test_tokens, test_tags = read_data('data/test.txt')

# %% [markdown]
# You should always understand what kind of data you deal with. For this purpose, you can print the data running the following cell:

# %%
for i in range(3):
    for token, tag in zip(train_tokens[i], train_tags[i]):
        print('%s\t%s' % (token, tag))
    print()
# Out:
# RT	O
# <USR>	O
# :	O
# Online	O
# ticket	O
# sales	O
# for	O
# Ghostland	B-musicartist
# Observatory	I-musicartist
# extended	O
# until	O
# 6	O
# PM	O
# EST	O
# due	O
# to	O
# high	O
# demand	O
# .	O
# Get	O
# them	O
# before	O
# they	O
# sell	O
# out	O
# ...	O
#
# Apple	B-product
# MacBook	I-product
# Pro	I-product
# A1278	I-product
# 13.3	I-product
# "	I-product
# Laptop	I-product
# -	I-product
# MD101LL/A	I-product
# (	O
# June	O
# ,	O
# 2012	O
# )	O
# -	O
# Full	O
# read	O
# by	O
# eBay	B-company
# <URL>	O
# <URL>	O
#
# Happy	O
# Birthday	O
# <USR>	O
# !	O
# May	O
# Allah	B-person
# s.w.t	O
# bless	O
# you	O
# with	O
# goodness	O
# and	O
# happiness	O
# .	O

# %% [markdown]
# ### Prepare dictionaries
#
# To train a neural network, we will use two mappings:
# - {token}$\to${token id}: address the row in embeddings matrix for the current token;
# - {tag}$\to${tag id}: one-hot ground truth probability distribution vectors for computing the loss at the output of the network.
#
# Now you need to implement the function *build_dict* which will return {token or tag}$\to${index} and vice versa.

# %%
from collections import defaultdict

# %%
def flatten_tokens(tokens_or_tags):
    for tokens_or_tags_list in tokens_or_tags:
        for token_or_tag in tokens_or_tags_list:
            yield token_or_tag

def build_dict(tokens_or_tags, special_tokens):
    """
        tokens_or_tags: a list of lists of tokens or tags
        special_tokens: some special tokens
    """
    # Create a dictionary with default value 0
    tok2idx = defaultdict(lambda: 0)
    idx2tok = []
    
    # Create mappings from tokens (or tags) to indices and vice versa.
    # At first, add special tokens (or tags) to the dictionaries.
    # The first special token must have index 0.
    special_tokens = set(special_tokens)
    special_tokens_enum = enumerate(special_tokens, 0)
    for (i, w) in special_tokens_enum:
        tok2idx[w] = i
        idx2tok.append(w)
    
    # Mapping tok2idx should contain each token or tag only once. 
    # To do so, you should:
    # 1. extract unique tokens/tags from the tokens_or_tags variable, which is not
    #    occur in special_tokens (because they could have non-empty intersection)
    # 2. index them (for example, you can add them into the list idx2tok
    # 3. for each token/tag save the index into tok2idx).
    all_tokens = set(filter(lambda t: t not in tok2idx, flatten_tokens(tokens_or_tags)))
    all_tokens_enum = enumerate(all_tokens, len(special_tokens))
    for (i, w) in all_tokens_enum:
        tok2idx[w] = i
        idx2tok.append(w)

    return tok2idx, idx2tok

# %% [markdown]
# After implementing the function *build_dict* you can make dictionaries for tokens and tags. Special tokens in our case will be:
#  - `<UNK>` token for out of vocabulary tokens;
#  - `<PAD>` token for padding sentence to the same length when we create batches of sentences.

# %%
special_tokens = ['<UNK>', '<PAD>']
special_tags = ['O']

# # Create dictionaries 
token2idx, idx2token = build_dict(train_tokens + validation_tokens, special_tokens)
tag2idx, idx2tag = build_dict(train_tags, special_tags)

# %% [markdown]
# The next additional functions will help you to create the mapping between tokens and ids for a sentence.

# %%
def words2idxs(tokens_list):
    return [token2idx[word] for word in tokens_list]

def tags2idxs(tags_list):
    return [tag2idx[tag] for tag in tags_list]

def idxs2words(idxs):
    return [idx2token[idx] for idx in idxs]

def idxs2tags(idxs):
    return [idx2tag[idx] for idx in idxs]

# %% [markdown]
# ### Generate batches
#
# Neural Networks are usually trained with batches. It means that weight updates of the network are based on several sequences at every single time. The tricky part is that all sequences within a batch need to have the same length. So we will pad them with a special `<PAD>` token. It is also a good practice to provide RNN with sequence lengths, so it can skip computations for padding parts. We provide the batching function *batches_generator* readily available for you to save time.

# %%
def batches_generator(batch_size, tokens, tags,
                      shuffle=True, allow_smaller_last_batch=True):
    """Generates padded batches of tokens and tags."""
    
    n_samples = len(tokens)
    if shuffle:
        order = np.random.permutation(n_samples)
    else:
        order = np.arange(n_samples)

    n_batches = n_samples // batch_size
    if allow_smaller_last_batch and n_samples % batch_size:
        n_batches += 1

    for k in range(n_batches):
        batch_start = k * batch_size
        batch_end = min((k + 1) * batch_size, n_samples)
        current_batch_size = batch_end - batch_start
        x_list = []
        y_list = []
        max_len_token = 0
        for idx in order[batch_start: batch_end]:
            x_list.append(words2idxs(tokens[idx]))
            y_list.append(tags2idxs(tags[idx]))
            max_len_token = max(max_len_token, len(tags[idx]))
            
        # Fill in the data into numpy nd-arrays filled with padding indices.
        x = np.ones([current_batch_size, max_len_token], dtype=np.int32) * token2idx['<PAD>']
        y = np.ones([current_batch_size, max_len_token], dtype=np.int32) * tag2idx['O']
        lengths = np.zeros(current_batch_size, dtype=np.int32)
        for n in range(current_batch_size):
            utt_len = len(x_list[n])
            x[n, :utt_len] = x_list[n]
            lengths[n] = utt_len
            y[n, :utt_len] = y_list[n]
        yield x, y, lengths

# %% [markdown]
# ## Build a recurrent neural network
#
# This is the most important part of the assignment. Here we will specify the network architecture based on TensorFlow building blocks. It's fun and easy as a lego constructor! We will create an LSTM network which will produce probability distribution over tags for each token in a sentence. To take into account both right and left contexts of the token, we will use Bi-Directional LSTM (Bi-LSTM). Dense layer will be used on top to perform tag classification.

# %%
import tensorflow as tf
import numpy as np
from tensorflow.python.training.adam import AdamOptimizer

# %%
class BiLSTMModel():
    pass

# %% [markdown]
# First, we need to create [placeholders](https://www.tensorflow.org/versions/master/api_docs/python/tf/placeholder) to specify what data we are going to feed into the network during the execution time.  For this task we will need the following placeholders:
#  - *input_batch* — sequences of words (the shape equals to [batch_size, sequence_len]);
#  - *ground_truth_tags* — sequences of tags (the shape equals to [batch_size, sequence_len]);
#  - *lengths* — lengths of not padded sequences (the shape equals to [batch_size]);
#  - *dropout_ph* — dropout keep probability; this placeholder has a predefined value 1;
#  - *learning_rate_ph* — learning rate; we need this placeholder because we want to change the value during training.
#
# It could be noticed that we use *None* in the shapes in the declaration, which means that data of any size can be feeded.
#
# You need to complete the function *declare_placeholders*.

# %%
def declare_placeholders(self):
    """Specifies placeholders for the model."""

    # Placeholders for input and ground truth output.
    self.input_batch = tf.placeholder(dtype=tf.int32, shape=[None, None], name='input_batch') 
    self.ground_truth_tags = tf.placeholder(dtype=tf.int32, shape=[None, None], name='ground_truth_tags') 
  
    # Placeholder for lengths of the sequences.
    self.lengths = tf.placeholder(dtype=tf.int32, shape=[None], name='lengths') 
    
    # Placeholder for a dropout keep probability. If we don't feed
    # a value for this placeholder, it will be equal to 1.0.
    self.dropout_ph = tf.placeholder_with_default(tf.cast(1.0, tf.float32), shape=[])
    
    # Placeholder for a learning rate (tf.float32).
    self.learning_rate_ph = tf.placeholder(dtype=tf.float32, shape=[], name='learning_rate_ph')

# %%
BiLSTMModel.__declare_placeholders = classmethod(declare_placeholders)

# %% [markdown]
# Now, let us specify the layers of the neural network. First, we need to perform some preparatory steps:
#
# - Create embeddings matrix with [tf.Variable](https://www.tensorflow.org/api_docs/python/tf/Variable). Specify its name (*embeddings_matrix*), type  (*tf.float32*), and initialize with random values.
# - Create forward and backward LSTM cells. TensorFlow provides a number of RNN cells ready for you. We suggest that you use *LSTMCell*, but you can also experiment with other types, e.g. GRU cells. [This](http://colah.github.io/posts/2015-08-Understanding-LSTMs/) blogpost could be interesting if you want to learn more about the differences.
# - Wrap your cells with [DropoutWrapper](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper). Dropout is an important regularization technique for neural networks. Specify all keep probabilities using the dropout placeholder that we created before.
#
# After that, you can build the computation graph that transforms an input_batch:
#
# - [Look up](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) embeddings for an *input_batch* in the prepared *embedding_matrix*.
# - Pass the embeddings through [Bidirectional Dynamic RNN](https://www.tensorflow.org/api_docs/python/tf/nn/bidirectional_dynamic_rnn) with the specified forward and backward cells. Use the lengths placeholder here to avoid computations for padding tokens inside the RNN.
# - Create a dense layer on top. Its output will be used directly in loss function.
#
# Fill in the code below. In case you need to debug something, the easiest way is to check that tensor shapes of each step match the expected ones.

# %%
def build_layers(self, vocabulary_size, embedding_dim, n_hidden_rnn, n_tags):
    """Specifies bi-LSTM architecture and computes logits for inputs."""
    
    # Create embedding variable (tf.Variable) with dtype tf.float32
    initial_embedding_matrix = np.random.randn(vocabulary_size, embedding_dim) / np.sqrt(embedding_dim)
    embedding_matrix_variable = tf.Variable(initial_embedding_matrix, 
                                            name="embedding_matrix", dtype= tf.float32)
    
    # Create RNN cells (for example, tf.nn.rnn_cell.BasicLSTMCell) with n_hidden_rnn number of units 
    # and dropout (tf.nn.rnn_cell.DropoutWrapper), initializing all *_keep_prob with dropout placeholder.
    forward_cell =  tf.nn.rnn_cell.LSTMCell(n_hidden_rnn) #
    backward_cell = tf.nn.rnn_cell.LSTMCell(n_hidden_rnn) # 
    forward_cell = tf.nn.rnn_cell.DropoutWrapper(forward_cell, 
                                         input_keep_prob=self.dropout_ph, 
                                         state_keep_prob=self.dropout_ph, 
                                         output_keep_prob=self.dropout_ph) #
    backward_cell = tf.nn.rnn_cell.DropoutWrapper(backward_cell, 
                                          input_keep_prob=self.dropout_ph, 
                                          state_keep_prob=self.dropout_ph, 
                                          output_keep_prob=self.dropout_ph) # 
        
    # Look up embeddings for self.input_batch (tf.nn.embedding_lookup).
    # Shape: [batch_size, sequence_len, embedding_dim].
    embeddings =  tf.nn.embedding_lookup(embedding_matrix_variable, self.input_batch)
    
    # Pass them through Bidirectional Dynamic RNN (tf.nn.bidirectional_dynamic_rnn).
    # Shape: [batch_size, sequence_len, 2 * n_hidden_rnn]. 
    # Also don't forget to initialize sequence_length as self.lengths and dtype as tf.float32.
    (rnn_output_fw, rnn_output_bw), _ = tf.nn.bidirectional_dynamic_rnn(forward_cell, 
                                                                        backward_cell, 
                                                                        embeddings,
                                                                        sequence_length=self.lengths,
                                                                        dtype=tf.float32)
    rnn_output = tf.concat([rnn_output_fw, rnn_output_bw], axis=2)

    # Dense layer on top.
    # Shape: [batch_size, sequence_len, n_tags].   
    self.logits = tf.layers.dense(rnn_output, n_tags, activation=None)

# %%
BiLSTMModel.__build_layers = classmethod(build_layers)

# %% [markdown]
# To compute the actual predictions of the neural network, you need to apply [softmax](https://www.tensorflow.org/api_docs/python/tf/nn/softmax) to the last layer and find the most probable tags with [argmax](https://www.tensorflow.org/api_docs/python/tf/argmax).

# %%
def compute_predictions(self):
    """Transforms logits to probabilities and finds the most probable tags."""
    
    # Create softmax (tf.nn.softmax) function
    softmax_output = tf.nn.softmax(self.logits)
    
    # Use argmax (tf.argmax) to get the most probable tags
    # Don't forget to set axis=-1
    # otherwise argmax will be calculated in a wrong way
    self.predictions = tf.argmax(softmax_output, axis=-1)

# %%
BiLSTMModel.__compute_predictions = classmethod(compute_predictions)

# %% [markdown]
# During training we do not need predictions of the network, but we need a loss function. We will use [cross-entropy loss](http://ml-cheatsheet.readthedocs.io/en/latest/loss_functions.html#cross-entropy), efficiently implemented in TF as
# [cross entropy with logits](https://www.tensorflow.org/api_docs/python/tf/nn/softmax_cross_entropy_with_logits_v2). Note that it should be applied to logits of the model (not to softmax probabilities!). Also note,  that we do not want to take into account loss terms coming from `<PAD>` tokens. So we need to mask them out, before computing [mean](https://www.tensorflow.org/api_docs/python/tf/reduce_mean).

# %%
def compute_loss(self, n_tags, PAD_index):
    """Computes masked cross-entopy loss with logits."""
    # Create cross entropy function function (tf.nn.softmax_cross_entropy_with_logits_v2)
    ground_truth_tags_one_hot = tf.one_hot(self.ground_truth_tags, n_tags)
    loss_tensor = tf.nn.softmax_cross_entropy_with_logits(labels=ground_truth_tags_one_hot, 
                                                                 logits=self.logits)
    
    mask = tf.cast(tf.not_equal(self.input_batch, PAD_index), dtype=tf.float32)
    # Create loss function which doesn't operate with <PAD> tokens (tf.reduce_mean)
    # Be careful that the argument of tf.reduce_mean should be
    # multiplication of mask and loss_tensor.
    arg = tf.multiply(mask, loss_tensor)
    self.loss = tf.reduce_mean(arg)  ######### YOUR CODE HERE #############

# %%
BiLSTMModel.__compute_loss = classmethod(compute_loss)

# %% [markdown]
# The last thing to specify is how we want to optimize the loss.
# We suggest that you use [Adam](https://www.tensorflow.org/api_docs/python/tf/train/AdamOptimizer) optimizer with a learning rate from the corresponding placeholder.
# You will also need to apply clipping to eliminate exploding gradients. It can be easily done with [clip_by_norm](https://www.tensorflow.org/api_docs/python/tf/clip_by_norm) function.

# %%
def perform_optimization(self):
    """Specifies the optimizer and train_op for the model."""
    
    # Create an optimizer (tf.train.AdamOptimizer)
    self.optimizer =  tf.train.AdamOptimizer(self.learning_rate_ph) ######### YOUR CODE HERE #############
    self.grads_and_vars = self.optimizer.compute_gradients(self.loss)
    
    # Gradient clipping (tf.clip_by_norm) for self.grads_and_vars
    # Pay attention that you need to apply this operation only for gradients 
    # because self.grads_and_vars also contains variables.
    # list comprehension might be useful in this case.
    clip_norm = tf.cast(1.0, tf.float32)
    self.grads_and_vars = [ (tf.clip_by_norm(grad, clip_norm), var) for grad, var in self.grads_and_vars]
    
    self.train_op = self.optimizer.apply_gradients(self.grads_and_vars)

# %%
BiLSTMModel.__perform_optimization = classmethod(perform_optimization)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-fd5e67618321> in <module>
# ----> 1 BiLSTMModel.__perform_optimization = classmethod(perform_optimization)
#
# NameError: name 'BiLSTMModel' is not defined

# %% [markdown]
# Congratulations! You have specified all the parts of your network. You may have noticed, that we didn't deal with any real data yet, so what you have written is just recipes on how the network should function.
# Now we will put them to the constructor of our Bi-LSTM class to use it in the next section.

# %%
def init_model(self, vocabulary_size, n_tags, embedding_dim, n_hidden_rnn, PAD_index):
    self.__declare_placeholders()
    self.__build_layers(vocabulary_size, embedding_dim, n_hidden_rnn, n_tags)
    self.__compute_predictions()
    self.__compute_loss(n_tags, PAD_index)
    self.__perform_optimization()

# %%
BiLSTMModel.__init__ = classmethod(init_model)

# %% [markdown]
# ## Train the network and predict tags

# %% [markdown]
# [Session.run](https://www.tensorflow.org/api_docs/python/tf/Session#run) is a point which initiates computations in the graph that we have defined. To train the network, we need to compute *self.train_op*, which was declared in *perform_optimization*. To predict tags, we just need to compute *self.predictions*. Anyway, we need to feed actual data through the placeholders that we defined before.

# %%
def train_on_batch(self, session, x_batch, y_batch, lengths, learning_rate, dropout_keep_probability):
    feed_dict = {self.input_batch: x_batch,
                 self.ground_truth_tags: y_batch,
                 self.learning_rate_ph: learning_rate,
                 self.dropout_ph: dropout_keep_probability,
                 self.lengths: lengths}
    
    session.run(self.train_op, feed_dict=feed_dict)

# %%
BiLSTMModel.train_on_batch = classmethod(train_on_batch)

# %% [markdown]
# Implement the function *predict_for_batch* by initializing *feed_dict* with input *x_batch* and *lengths* and running the *session* for *self.predictions*.

# %%
def predict_for_batch(self, session, x_batch, lengths):
    feed_dict = {self.input_batch: x_batch,
                 self.lengths: lengths}
    
    predictions = session.run(self.predictions, feed_dict=feed_dict)
    
    return predictions

# %%
BiLSTMModel.predict_for_batch = classmethod(predict_for_batch)

# %% [markdown]
# We finished with necessary methods of our BiLSTMModel model and almost ready to start experimenting.
#
# ### Evaluation
# To simplify the evaluation process we provide two functions for you:
#  - *predict_tags*: uses a model to get predictions and transforms indices to tokens and tags;
#  - *eval_conll*: calculates precision, recall and F1 for the results.

# %%
from evaluation import precision_recall_f1

# %%
def predict_tags(model, session, token_idxs_batch, lengths):
    """Performs predictions and transforms indices to tokens and tags."""
    
    tag_idxs_batch = model.predict_for_batch(session, token_idxs_batch, lengths)
    
    tags_batch, tokens_batch = [], []
    for tag_idxs, token_idxs in zip(tag_idxs_batch, token_idxs_batch):
        tags, tokens = [], []
        for tag_idx, token_idx in zip(tag_idxs, token_idxs):
            tags.append(idx2tag[tag_idx])
            tokens.append(idx2token[token_idx])
        tags_batch.append(tags)
        tokens_batch.append(tokens)
    return tags_batch, tokens_batch
    
    
def eval_conll(model, session, tokens, tags, short_report=True):
    """Computes NER quality measures using CONLL shared task script."""
    
    y_true, y_pred = [], []
    for x_batch, y_batch, lengths in batches_generator(1, tokens, tags):
        tags_batch, tokens_batch = predict_tags(model, session, x_batch, lengths)
        if len(x_batch[0]) != len(tags_batch[0]):
            raise Exception("Incorrect length of prediction for the input, "
                            "expected length: %i, got: %i" % (len(x_batch[0]), len(tags_batch[0])))
        predicted_tags = []
        ground_truth_tags = []
        for gt_tag_idx, pred_tag, token in zip(y_batch[0], tags_batch[0], tokens_batch[0]): 
            if token != '<PAD>':
                ground_truth_tags.append(idx2tag[gt_tag_idx])
                predicted_tags.append(pred_tag)

        # We extend every prediction and ground truth sequence with 'O' tag
        # to indicate a possible end of entity.
        y_true.extend(ground_truth_tags + ['O'])
        y_pred.extend(predicted_tags + ['O'])
        
    results = precision_recall_f1(y_true, y_pred, print_results=True, short_report=short_report)
    return results

# %% [markdown]
# ## Run your experiment

# %% [markdown]
# Create *BiLSTMModel* model with the following parameters:
#  - *vocabulary_size* — number of tokens;
#  - *n_tags* — number of tags;
#  - *embedding_dim* — dimension of embeddings, recommended value: 200;
#  - *n_hidden_rnn* — size of hidden layers for RNN, recommended value: 200;
#  - *PAD_index* — an index of the padding token (`<PAD>`).
#
# Set hyperparameters. You might want to start with the following recommended values:
# - *batch_size*: 32;
# - 4 epochs;
# - starting value of *learning_rate*: 0.005
# - *learning_rate_decay*: a square root of 2;
# - *dropout_keep_probability*: try several values: 0.1, 0.5, 0.9.
#
# However, feel free to conduct more experiments to tune hyperparameters and earn extra points for the assignment.

# %%
import tensorflow as tf
tf.reset_default_graph()

pad_index = token2idx['<PAD>']
tags_size = len(tag2idx.keys())
vocab_size = len(token2idx.keys())
print("Number of tags", tags_size)
print("Vocabulary size", vocab_size)
print('<PAD> index: ', pad_index)
#vocabulary_size, n_tags, embedding_dim, n_hidden_rnn, PAD_index
model = BiLSTMModel(vocabulary_size=vocab_size, n_tags=tags_size, embedding_dim=200, n_hidden_rnn=200, PAD_index=pad_index)
batch_size = 32
n_epochs = 4
learning_rate = 0.005
learning_rate_decay = np.sqrt(2.0)
dropout_keep_probability = 0.5
# Out:
# Number of tags 21
# Vocabulary size 20467
# <PAD> index:  1

# %% [markdown]
# If you got an error *"Tensor conversion requested dtype float64 for Tensor with dtype float32"* in this point, check if there are variables without dtype initialised. Set the value of dtype equals to *tf.float32* for such variables.

# %% [markdown]
# Finally, we are ready to run the training!

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

print('Start training... \n')
for epoch in range(n_epochs):
    # For each epoch evaluate the model on train and validation data
    print('-' * 20 + ' Epoch {} '.format(epoch+1) + 'of {} '.format(n_epochs) + '-' * 20)
    print('Train data evaluation:')
    eval_conll(model, sess, train_tokens, train_tags, short_report=True)
    print('Validation data evaluation:')
    eval_conll(model, sess, validation_tokens, validation_tags, short_report=True)
    
    # Train the model
    for x_batch, y_batch, lengths in batches_generator(batch_size, train_tokens, train_tags):
        model.train_on_batch(sess, x_batch, y_batch, lengths, learning_rate, dropout_keep_probability)
        
    # Decaying the learning rate
    learning_rate = learning_rate / learning_rate_decay
    
print('...training finished.')
# Out:
# Start training...
#
# -------------------- Epoch 1 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 77199 phrases; correct: 149.
#
# precision:  0.19%; recall:  3.32%; F1:  0.36
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 9335 phrases; correct: 15.
#
# precision:  0.16%; recall:  2.79%; F1:  0.30
#
# -------------------- Epoch 2 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 2261 phrases; correct: 528.
#
# precision:  23.35%; recall:  11.76%; F1:  15.64
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 204 phrases; correct: 42.
#
# precision:  20.59%; recall:  7.82%; F1:  11.34
#
# -------------------- Epoch 3 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 5078 phrases; correct: 2060.
#
# precision:  40.57%; recall:  45.89%; F1:  43.06
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 395 phrases; correct: 155.
#
# precision:  39.24%; recall:  28.86%; F1:  33.26
#
# -------------------- Epoch 4 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 4601 phrases; correct: 3112.
#
# precision:  67.64%; recall:  69.33%; F1:  68.47
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 392 phrases; correct: 175.
#
# precision:  44.64%; recall:  32.59%; F1:  37.67
#
# ...training finished.

# %% [markdown]
# Now let us see full quality reports for the final model on train, validation, and test sets. To give you a hint whether you have implemented everything correctly, you might expect F-score about 40% on the validation set.
#
# **The output of the cell below (as well as the output of all the other cells) should be present in the notebook for peer2peer review!**

# %%
print('-' * 20 + ' Train set quality: ' + '-' * 20)
train_results = eval_conll(model, sess, train_tokens, train_tags, short_report=False)

print('-' * 20 + ' Validation set quality: ' + '-' * 20)
validation_results = eval_conll(model, sess, validation_tokens, validation_tags, short_report=False)

print('-' * 20 + ' Test set quality: ' + '-' * 20)
test_results = eval_conll(model, sess, test_tokens, test_tags, short_report=False)
# Out:
# -------------------- Train set quality: --------------------
# processed 105778 tokens with 4489 phrases; found: 4691 phrases; correct: 3504.
#
# precision:  74.70%; recall:  78.06%; F1:  76.34
#
# 	     company: precision:   84.35%; recall:   92.22%; F1:   88.11; predicted:   703
#
# 	    facility: precision:   82.06%; recall:   78.66%; F1:   80.33; predicted:   301
#
# 	     geo-loc: precision:   80.64%; recall:   96.18%; F1:   87.73; predicted:  1188
#
# 	       movie: precision:   17.24%; recall:    7.35%; F1:   10.31; predicted:    29
#
# 	 musicartist: precision:   24.81%; recall:   14.22%; F1:   18.08; predicted:   133
#
# 	       other: precision:   76.16%; recall:   82.69%; F1:   79.29; predicted:   822
#
# 	      person: precision:   70.64%; recall:   94.24%; F1:   80.75; predicted:  1182
#
# 	     product: precision:   62.04%; recall:   63.21%; F1:   62.62; predicted:   324
#
# 	  sportsteam: precision:   66.67%; recall:    2.76%; F1:    5.31; predicted:     9
#
# 	      tvshow: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     0
#
# -------------------- Validation set quality: --------------------
# processed 12836 tokens with 537 phrases; found: 415 phrases; correct: 195.
#
# precision:  46.99%; recall:  36.31%; F1:  40.97
#
# 	     company: precision:   59.38%; recall:   54.81%; F1:   57.00; predicted:    96
#
# 	    facility: precision:   42.31%; recall:   32.35%; F1:   36.67; predicted:    26
#
# 	     geo-loc: precision:   59.80%; recall:   53.98%; F1:   56.74; predicted:   102
#
# 	       movie: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     0
#
# 	 musicartist: precision:    5.26%; recall:    3.57%; F1:    4.26; predicted:    19
#
# 	       other: precision:   35.06%; recall:   33.33%; F1:   34.18; predicted:    77
#
# 	      person: precision:   42.68%; recall:   31.25%; F1:   36.08; predicted:    82
#
# 	     product: precision:   23.08%; recall:    8.82%; F1:   12.77; predicted:    13
#
# 	  sportsteam: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     0
#
# 	      tvshow: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     0
#
# -------------------- Test set quality: --------------------
# processed 13258 tokens with 604 phrases; found: 463 phrases; correct: 231.
#
# precision:  49.89%; recall:  38.25%; F1:  43.30
#
# 	     company: precision:   45.45%; recall:   41.67%; F1:   43.48; predicted:    77
#
# 	    facility: precision:   58.06%; recall:   38.30%; F1:   46.15; predicted:    31
#
# 	     geo-loc: precision:   69.23%; recall:   54.55%; F1:   61.02; predicted:   130
#
# 	       movie: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     1
#
# 	 musicartist: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:    11
#
# 	       other: precision:   35.29%; recall:   34.95%; F1:   35.12; predicted:   102
#
# 	      person: precision:   49.49%; recall:   47.12%; F1:   48.28; predicted:    99
#
# 	     product: precision:   27.27%; recall:   10.71%; F1:   15.38; predicted:    11
#
# 	  sportsteam: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     1
#
# 	      tvshow: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     0

# %% [markdown]
# # Experimentation on learning rate and dropout

# %%
def build_model(l=0.005, r=np.sqrt(2.0), d=0.5):
    tf.reset_default_graph()
    pad_index = token2idx['<PAD>']
    tags_size = len(tag2idx.keys())
    vocab_size = len(token2idx.keys())
    model = BiLSTMModel(vocabulary_size=vocab_size, n_tags=tags_size, embedding_dim=200, n_hidden_rnn=200, PAD_index=pad_index)
    return model

def print_results(model, sess, short_report=False):
    print('-' * 20 + ' Train set quality: ' + '-' * 20)
    train_results = eval_conll(model, sess, train_tokens, train_tags, short_report=short_report)

    print('-' * 20 + ' Validation set quality: ' + '-' * 20)
    validation_results = eval_conll(model, sess, validation_tokens, validation_tags, short_report=short_report)

    print('-' * 20 + ' Test set quality: ' + '-' * 20)
    test_results = eval_conll(model, sess, test_tokens, test_tags, short_report=short_report)
    
def train_model(model, learning_rate=0.1, learning_rate_decay=np.sqrt(2.0), dropout_keep_probability=0.5):
    sess = tf.Session()
    sess.run(tf.global_variables_initializer())
    batch_size = 32
    n_epochs = 4
    
    print('Start training... \n')
    for epoch in range(n_epochs):
        # For each epoch evaluate the model on train and validation data
        print('-' * 20 + ' Epoch {} '.format(epoch+1) + 'of {} '.format(n_epochs) + '-' * 20)
        print('Train data evaluation:')
        eval_conll(model, sess, train_tokens, train_tags, short_report=True)
        print('Validation data evaluation:')
        eval_conll(model, sess, validation_tokens, validation_tags, short_report=True)

        # Train the model
        for x_batch, y_batch, lengths in batches_generator(batch_size, train_tokens, train_tags):
            model.train_on_batch(sess, x_batch, y_batch, lengths, learning_rate, dropout_keep_probability)

        # Decaying the learning rate
        learning_rate = learning_rate / learning_rate_decay

    print('...training finished.')
    print_results(model, sess)

# %%
for l in [0.01, 0.005]:
    for r in [np.sqrt(2.0), np.sqrt(2.5)]:
        for d in [0.5,  0.9]:
            model = build_model()
            print("\n\nTraining model wiht parameters:")
            print("\nLearning rate: ", l)
            print("\nLearning rated decay: ", r)
            print("\nDropout: ", d)
            train_model(model, l, r, d)
# Out:
# Training model wiht parameters:
#
# Learning rate:  0.01
#
# Learning rated decay:  1.41421356237
#
# Dropout:  0.5
# Start training...
#
# -------------------- Epoch 1 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 78385 phrases; correct: 176.
#
# precision:  0.22%; recall:  3.92%; F1:  0.42
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 9469 phrases; correct: 19.
#
# precision:  0.20%; recall:  3.54%; F1:  0.38
#
# -------------------- Epoch 2 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 2980 phrases; correct: 1365.
#
# precision:  45.81%; recall:  30.41%; F1:  36.55
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 233 phrases; correct: 107.
#
# precision:  45.92%; recall:  19.93%; F1:  27.79
#
# -------------------- Epoch 3 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 4479 phrases; correct: 3041.
#
# precision:  67.89%; recall:  67.74%; F1:  67.82
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 368 phrases; correct: 175.
#
# precision:  47.55%; recall:  32.59%; F1:  38.67
#
# -------------------- Epoch 4 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 4784 phrases; correct: 3908.
#
# precision:  81.69%; recall:  87.06%; F1:  84.29
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 436 phrases; correct: 200.
#
# precision:  45.87%; recall:  37.24%; F1:  41.11
#
# ...training finished.
# -------------------- Train set quality: --------------------
# processed 105778 tokens with 4489 phrases; found: 4640 phrases; correct: 4149.
#
# precision:  89.42%; recall:  92.43%; F1:  90.90
#
# 	     company: precision:   93.59%; recall:   95.33%; F1:   94.45; predicted:   655
#
# 	    facility: precision:   88.38%; recall:   92.04%; F1:   90.17; predicted:   327
#
# 	     geo-loc: precision:   93.20%; recall:   97.69%; F1:   95.39; predicted:  1044
#
# 	       movie: precision:   54.95%; recall:   73.53%; F1:   62.89; predicted:    91
#
# 	 musicartist: precision:   73.20%; recall:   91.81%; F1:   81.45; predicted:   291
#
# 	       other: precision:   90.04%; recall:   91.94%; F1:   90.98; predicted:   773
#
# 	      person: precision:   94.57%; recall:   94.36%; F1:   94.46; predicted:   884
#
# 	     product: precision:   86.64%; recall:   83.65%; F1:   85.12; predicted:   307
#
# 	  sportsteam: precision:   84.21%; recall:   88.48%; F1:   86.29; predicted:   228
#
# 	      tvshow: precision:   52.50%; recall:   36.21%; F1:   42.86; predicted:    40
#
# -------------------- Validation set quality: --------------------
# processed 12836 tokens with 537 phrases; found: 423 phrases; correct: 205.
#
# precision:  48.46%; recall:  38.18%; F1:  42.71
#
# 	     company: precision:   65.52%; recall:   54.81%; F1:   59.69; predicted:    87
#
# 	    facility: precision:   46.88%; recall:   44.12%; F1:   45.45; predicted:    32
#
# 	     geo-loc: precision:   66.30%; recall:   53.98%; F1:   59.51; predicted:    92
#
# 	       movie: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:    16
#
# 	 musicartist: precision:   18.18%; recall:   21.43%; F1:   19.67; predicted:    33
#
# 	       other: precision:   36.76%; recall:   30.86%; F1:   33.56; predicted:    68
#
# 	      person: precision:   55.00%; recall:   29.46%; F1:   38.37; predicted:    60
#
# 	     product: precision:   23.53%; recall:   11.76%; F1:   15.69; predicted:    17
#
# 	  sportsteam: precision:   22.22%; recall:   20.00%; F1:   21.05; predicted:    18
#
# 	      tvshow: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     0
#
# -------------------- Test set quality: --------------------
# processed 13258 tokens with 604 phrases; found: 472 phrases; correct: 244.
#
# precision:  51.69%; recall:  40.40%; F1:  45.35
#
# 	     company: precision:   65.52%; recall:   45.24%; F1:   53.52; predicted:    58
#
# 	    facility: precision:   48.78%; recall:   42.55%; F1:   45.45; predicted:    41
#
# 	     geo-loc: precision:   71.32%; recall:   55.76%; F1:   62.59; predicted:   129
#
# 	       movie: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     3
#
# 	 musicartist: precision:    8.70%; recall:    7.41%; F1:    8.00; predicted:    23
#
# 	       other: precision:   36.19%; recall:   36.89%; F1:   36.54; predicted:   105
#
# 	      person: precision:   60.61%; recall:   38.46%; F1:   47.06; predicted:    66
#
# 	     product: precision:   26.32%; recall:   17.86%; F1:   21.28; predicted:    19
#
# 	  sportsteam: precision:   34.62%; recall:   29.03%; F1:   31.58; predicted:    26
#
# 	      tvshow: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     2
#
#
#
# Training model wiht parameters:
#
# Learning rate:  0.01
#
# Learning rated decay:  1.41421356237
#
# Dropout:  0.9
# Start training...
#
# -------------------- Epoch 1 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 73895 phrases; correct: 174.
#
# precision:  0.24%; recall:  3.88%; F1:  0.44
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 9022 phrases; correct: 29.
#
# precision:  0.32%; recall:  5.40%; F1:  0.61
#
# -------------------- Epoch 2 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 3831 phrases; correct: 1993.
#
# precision:  52.02%; recall:  44.40%; F1:  47.91
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 300 phrases; correct: 138.
#
# precision:  46.00%; recall:  25.70%; F1:  32.97
#
# -------------------- Epoch 3 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 4653 phrases; correct: 3415.
#
# precision:  73.39%; recall:  76.07%; F1:  74.71
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 352 phrases; correct: 171.
#
# precision:  48.58%; recall:  31.84%; F1:  38.47
#
# -------------------- Epoch 4 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 4771 phrases; correct: 4188.
#
# precision:  87.78%; recall:  93.29%; F1:  90.45
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 524 phrases; correct: 211.
#
# precision:  40.27%; recall:  39.29%; F1:  39.77
#
# ...training finished.
# -------------------- Train set quality: --------------------
# processed 105778 tokens with 4489 phrases; found: 4558 phrases; correct: 4399.
#
# precision:  96.51%; recall:  98.00%; F1:  97.25
#
# 	     company: precision:   96.47%; recall:   97.67%; F1:   97.06; predicted:   651
#
# 	    facility: precision:   93.83%; recall:   96.82%; F1:   95.30; predicted:   324
#
# 	     geo-loc: precision:   97.54%; recall:   99.50%; F1:   98.51; predicted:  1016
#
# 	       movie: precision:   89.33%; recall:   98.53%; F1:   93.71; predicted:    75
#
# 	 musicartist: precision:   93.78%; recall:   97.41%; F1:   95.56; predicted:   241
#
# 	       other: precision:   96.63%; recall:   98.55%; F1:   97.58; predicted:   772
#
# 	      person: precision:   98.20%; recall:   98.76%; F1:   98.48; predicted:   891
#
# 	     product: precision:   97.11%; recall:   94.97%; F1:   96.03; predicted:   311
#
# 	  sportsteam: precision:   96.71%; recall:   94.93%; F1:   95.81; predicted:   213
#
# 	      tvshow: precision:   84.38%; recall:   93.10%; F1:   88.52; predicted:    64
#
# -------------------- Validation set quality: --------------------
# processed 12836 tokens with 537 phrases; found: 439 phrases; correct: 204.
#
# precision:  46.47%; recall:  37.99%; F1:  41.80
#
# 	     company: precision:   67.47%; recall:   53.85%; F1:   59.89; predicted:    83
#
# 	    facility: precision:   43.59%; recall:   50.00%; F1:   46.58; predicted:    39
#
# 	     geo-loc: precision:   65.17%; recall:   51.33%; F1:   57.43; predicted:    89
#
# 	       movie: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:    20
#
# 	 musicartist: precision:   38.46%; recall:   17.86%; F1:   24.39; predicted:    13
#
# 	       other: precision:   38.57%; recall:   33.33%; F1:   35.76; predicted:    70
#
# 	      person: precision:   50.82%; recall:   27.68%; F1:   35.84; predicted:    61
#
# 	     product: precision:   17.86%; recall:   14.71%; F1:   16.13; predicted:    28
#
# 	  sportsteam: precision:   25.00%; recall:   25.00%; F1:   25.00; predicted:    20
#
# 	      tvshow: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:    16
#
# -------------------- Test set quality: --------------------
# processed 13258 tokens with 604 phrases; found: 492 phrases; correct: 247.
#
# precision:  50.20%; recall:  40.89%; F1:  45.07
#
# 	     company: precision:   67.86%; recall:   45.24%; F1:   54.29; predicted:    56
#
# 	    facility: precision:   40.43%; recall:   40.43%; F1:   40.43; predicted:    47
#
# 	     geo-loc: precision:   75.61%; recall:   56.36%; F1:   64.58; predicted:   123
#
# 	       movie: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:    14
#
# 	 musicartist: precision:    5.88%; recall:    3.70%; F1:    4.55; predicted:    17
#
# 	       other: precision:   36.94%; recall:   39.81%; F1:   38.32; predicted:   111
#
# 	      person: precision:   64.62%; recall:   40.38%; F1:   49.70; predicted:    65
#
# 	     product: precision:   12.00%; recall:   10.71%; F1:   11.32; predicted:    25
#
# 	  sportsteam: precision:   45.45%; recall:   32.26%; F1:   37.74; predicted:    22
#
# 	      tvshow: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:    12
#
#
#
# Training model wiht parameters:
#
# Learning rate:  0.01
#
# Learning rated decay:  1.58113883008
#
# Dropout:  0.5
# Start training...
#
# -------------------- Epoch 1 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 73531 phrases; correct: 174.
#
# precision:  0.24%; recall:  3.88%; F1:  0.45
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 8936 phrases; correct: 23.
#
# precision:  0.26%; recall:  4.28%; F1:  0.49
#
# -------------------- Epoch 2 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 3342 phrases; correct: 1330.
#
# precision:  39.80%; recall:  29.63%; F1:  33.97
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 262 phrases; correct: 108.
#
# precision:  41.22%; recall:  20.11%; F1:  27.03
#
# -------------------- Epoch 3 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 4518 phrases; correct: 2899.
#
# precision:  64.17%; recall:  64.58%; F1:  64.37
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 370 phrases; correct: 164.
#
# precision:  44.32%; recall:  30.54%; F1:  36.16
#
# -------------------- Epoch 4 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 4771 phrases; correct: 3635.
#
# precision:  76.19%; recall:  80.98%; F1:  78.51
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 396 phrases; correct: 192.
#
# precision:  48.48%; recall:  35.75%; F1:  41.16
#
# ...training finished.
# -------------------- Train set quality: --------------------
# processed 105778 tokens with 4489 phrases; found: 4668 phrases; correct: 4047.
#
# precision:  86.70%; recall:  90.15%; F1:  88.39
#
# 	     company: precision:   90.03%; recall:   95.49%; F1:   92.68; predicted:   682
#
# 	    facility: precision:   83.18%; recall:   88.22%; F1:   85.63; predicted:   333
#
# 	     geo-loc: precision:   90.47%; recall:   96.29%; F1:   93.29; predicted:  1060
#
# 	       movie: precision:   44.78%; recall:   44.12%; F1:   44.44; predicted:    67
#
# 	 musicartist: precision:   74.17%; recall:   76.72%; F1:   75.42; predicted:   240
#
# 	       other: precision:   86.65%; recall:   90.89%; F1:   88.72; predicted:   794
#
# 	      person: precision:   91.23%; recall:   96.28%; F1:   93.68; predicted:   935
#
# 	     product: precision:   82.30%; recall:   83.33%; F1:   82.81; predicted:   322
#
# 	  sportsteam: precision:   78.47%; recall:   75.58%; F1:   77.00; predicted:   209
#
# 	      tvshow: precision:   73.08%; recall:   32.76%; F1:   45.24; predicted:    26
#
# -------------------- Validation set quality: --------------------
# processed 12836 tokens with 537 phrases; found: 400 phrases; correct: 197.
#
# precision:  49.25%; recall:  36.69%; F1:  42.05
#
# 	     company: precision:   62.37%; recall:   55.77%; F1:   58.88; predicted:    93
#
# 	    facility: precision:   37.93%; recall:   32.35%; F1:   34.92; predicted:    29
#
# 	     geo-loc: precision:   65.17%; recall:   51.33%; F1:   57.43; predicted:    89
#
# 	       movie: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     4
#
# 	 musicartist: precision:   40.00%; recall:   14.29%; F1:   21.05; predicted:    10
#
# 	       other: precision:   38.81%; recall:   32.10%; F1:   35.14; predicted:    67
#
# 	      person: precision:   53.33%; recall:   28.57%; F1:   37.21; predicted:    60
#
# 	     product: precision:    8.57%; recall:    8.82%; F1:    8.70; predicted:    35
#
# 	  sportsteam: precision:   41.67%; recall:   25.00%; F1:   31.25; predicted:    12
#
# 	      tvshow: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     1
#
# -------------------- Test set quality: --------------------
# processed 13258 tokens with 604 phrases; found: 437 phrases; correct: 249.
#
# precision:  56.98%; recall:  41.23%; F1:  47.84
#
# 	     company: precision:   60.66%; recall:   44.05%; F1:   51.03; predicted:    61
#
# 	    facility: precision:   51.35%; recall:   40.43%; F1:   45.24; predicted:    37
#
# 	     geo-loc: precision:   75.20%; recall:   56.97%; F1:   64.83; predicted:   125
#
# 	       movie: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     4
#
# 	 musicartist: precision:   18.18%; recall:    7.41%; F1:   10.53; predicted:    11
#
# 	       other: precision:   36.63%; recall:   35.92%; F1:   36.27; predicted:   101
#
# 	      person: precision:   69.23%; recall:   43.27%; F1:   53.25; predicted:    65
#
# 	     product: precision:   38.46%; recall:   17.86%; F1:   24.39; predicted:    13
#
# 	  sportsteam: precision:   50.00%; recall:   32.26%; F1:   39.22; predicted:    20
#
# 	      tvshow: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     0
#
#
#
# Training model wiht parameters:
#
# Learning rate:  0.01
#
# Learning rated decay:  1.58113883008
#
# Dropout:  0.9
# Start training...
#
# -------------------- Epoch 1 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 78561 phrases; correct: 193.
#
# precision:  0.25%; recall:  4.30%; F1:  0.46
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 9552 phrases; correct: 25.
#
# precision:  0.26%; recall:  4.66%; F1:  0.50
#
# -------------------- Epoch 2 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 3944 phrases; correct: 2072.
#
# precision:  52.54%; recall:  46.16%; F1:  49.14
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 306 phrases; correct: 148.
#
# precision:  48.37%; recall:  27.56%; F1:  35.11
#
# -------------------- Epoch 3 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 4741 phrases; correct: 3626.
#
# precision:  76.48%; recall:  80.78%; F1:  78.57
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 401 phrases; correct: 200.
#
# precision:  49.88%; recall:  37.24%; F1:  42.64
#
# -------------------- Epoch 4 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 4623 phrases; correct: 4216.
#
# precision:  91.20%; recall:  93.92%; F1:  92.54
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 435 phrases; correct: 205.
#
# precision:  47.13%; recall:  38.18%; F1:  42.18
#
# ...training finished.
# -------------------- Train set quality: --------------------
# processed 105778 tokens with 4489 phrases; found: 4524 phrases; correct: 4388.
#
# precision:  96.99%; recall:  97.75%; F1:  97.37
#
# 	     company: precision:   97.97%; recall:   97.67%; F1:   97.82; predicted:   641
#
# 	    facility: precision:   93.90%; recall:   98.09%; F1:   95.95; predicted:   328
#
# 	     geo-loc: precision:   98.50%; recall:   99.20%; F1:   98.85; predicted:  1003
#
# 	       movie: precision:   94.20%; recall:   95.59%; F1:   94.89; predicted:    69
#
# 	 musicartist: precision:   91.80%; recall:   96.55%; F1:   94.12; predicted:   244
#
# 	       other: precision:   95.20%; recall:   96.96%; F1:   96.07; predicted:   771
#
# 	      person: precision:   99.32%; recall:   98.65%; F1:   98.98; predicted:   880
#
# 	     product: precision:   96.30%; recall:   98.11%; F1:   97.20; predicted:   324
#
# 	  sportsteam: precision:   99.04%; recall:   94.93%; F1:   96.94; predicted:   208
#
# 	      tvshow: precision:   87.50%; recall:   84.48%; F1:   85.96; predicted:    56
#
# -------------------- Validation set quality: --------------------
# processed 12836 tokens with 537 phrases; found: 382 phrases; correct: 199.
#
# precision:  52.09%; recall:  37.06%; F1:  43.31
#
# 	     company: precision:   74.36%; recall:   55.77%; F1:   63.74; predicted:    78
#
# 	    facility: precision:   39.47%; recall:   44.12%; F1:   41.67; predicted:    38
#
# 	     geo-loc: precision:   67.07%; recall:   48.67%; F1:   56.41; predicted:    82
#
# 	       movie: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     3
#
# 	 musicartist: precision:   40.00%; recall:   14.29%; F1:   21.05; predicted:    10
#
# 	       other: precision:   35.14%; recall:   32.10%; F1:   33.55; predicted:    74
#
# 	      person: precision:   57.41%; recall:   27.68%; F1:   37.35; predicted:    54
#
# 	     product: precision:   18.52%; recall:   14.71%; F1:   16.39; predicted:    27
#
# 	  sportsteam: precision:   38.46%; recall:   25.00%; F1:   30.30; predicted:    13
#
# 	      tvshow: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     3
#
# -------------------- Test set quality: --------------------
# processed 13258 tokens with 604 phrases; found: 429 phrases; correct: 238.
#
# precision:  55.48%; recall:  39.40%; F1:  46.08
#
# 	     company: precision:   64.29%; recall:   42.86%; F1:   51.43; predicted:    56
#
# 	    facility: precision:   57.14%; recall:   42.55%; F1:   48.78; predicted:    35
#
# 	     geo-loc: precision:   80.18%; recall:   53.94%; F1:   64.49; predicted:   111
#
# 	       movie: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     3
#
# 	 musicartist: precision:   16.67%; recall:    7.41%; F1:   10.26; predicted:    12
#
# 	       other: precision:   32.46%; recall:   35.92%; F1:   34.10; predicted:   114
#
# 	      person: precision:   68.25%; recall:   41.35%; F1:   51.50; predicted:    63
#
# 	     product: precision:   18.75%; recall:   10.71%; F1:   13.64; predicted:    16
#
# 	  sportsteam: precision:   47.06%; recall:   25.81%; F1:   33.33; predicted:    17
#
# 	      tvshow: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     2
#
#
#
# Training model wiht parameters:
#
# Learning rate:  0.005
#
# Learning rated decay:  1.41421356237
#
# Dropout:  0.5
# Start training...
#
# -------------------- Epoch 1 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 75383 phrases; correct: 167.
#
# precision:  0.22%; recall:  3.72%; F1:  0.42
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 8966 phrases; correct: 25.
#
# precision:  0.28%; recall:  4.66%; F1:  0.53
#
# -------------------- Epoch 2 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 4109 phrases; correct: 798.
#
# precision:  19.42%; recall:  17.78%; F1:  18.56
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 320 phrases; correct: 54.
#
# precision:  16.88%; recall:  10.06%; F1:  12.60
#
# -------------------- Epoch 3 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 4793 phrases; correct: 1999.
#
# precision:  41.71%; recall:  44.53%; F1:  43.07
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 375 phrases; correct: 135.
#
# precision:  36.00%; recall:  25.14%; F1:  29.61
#
# -------------------- Epoch 4 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 4642 phrases; correct: 3055.
#
# precision:  65.81%; recall:  68.06%; F1:  66.91
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 374 phrases; correct: 172.
#
# precision:  45.99%; recall:  32.03%; F1:  37.76
#
# ...training finished.
# -------------------- Train set quality: --------------------
# processed 105778 tokens with 4489 phrases; found: 4698 phrases; correct: 3568.
#
# precision:  75.95%; recall:  79.48%; F1:  77.67
#
# 	     company: precision:   80.06%; recall:   90.51%; F1:   84.96; predicted:   727
#
# 	    facility: precision:   78.41%; recall:   75.16%; F1:   76.75; predicted:   301
#
# 	     geo-loc: precision:   81.29%; recall:   95.08%; F1:   87.64; predicted:  1165
#
# 	       movie: precision:   37.93%; recall:   16.18%; F1:   22.68; predicted:    29
#
# 	 musicartist: precision:   57.25%; recall:   34.05%; F1:   42.70; predicted:   138
#
# 	       other: precision:   75.59%; recall:   85.07%; F1:   80.05; predicted:   852
#
# 	      person: precision:   75.80%; recall:   93.34%; F1:   83.66; predicted:  1091
#
# 	     product: precision:   59.77%; recall:   66.35%; F1:   62.89; predicted:   353
#
# 	  sportsteam: precision:   73.81%; recall:   14.29%; F1:   23.94; predicted:    42
#
# 	      tvshow: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     0
#
# -------------------- Validation set quality: --------------------
# processed 12836 tokens with 537 phrases; found: 435 phrases; correct: 189.
#
# precision:  43.45%; recall:  35.20%; F1:  38.89
#
# 	     company: precision:   58.33%; recall:   53.85%; F1:   56.00; predicted:    96
#
# 	    facility: precision:   55.00%; recall:   32.35%; F1:   40.74; predicted:    20
#
# 	     geo-loc: precision:   62.11%; recall:   52.21%; F1:   56.73; predicted:    95
#
# 	       movie: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     2
#
# 	 musicartist: precision:   20.00%; recall:    7.14%; F1:   10.53; predicted:    10
#
# 	       other: precision:   23.47%; recall:   28.40%; F1:   25.70; predicted:    98
#
# 	      person: precision:   43.04%; recall:   30.36%; F1:   35.60; predicted:    79
#
# 	     product: precision:    8.82%; recall:    8.82%; F1:    8.82; predicted:    34
#
# 	  sportsteam: precision:  100.00%; recall:    5.00%; F1:    9.52; predicted:     1
#
# 	      tvshow: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     0
#
# -------------------- Test set quality: --------------------
# processed 13258 tokens with 604 phrases; found: 456 phrases; correct: 218.
#
# precision:  47.81%; recall:  36.09%; F1:  41.13
#
# 	     company: precision:   50.75%; recall:   40.48%; F1:   45.03; predicted:    67
#
# 	    facility: precision:   61.54%; recall:   34.04%; F1:   43.84; predicted:    26
#
# 	     geo-loc: precision:   69.12%; recall:   56.97%; F1:   62.46; predicted:   136
#
# 	       movie: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     1
#
# 	 musicartist: precision:   50.00%; recall:    7.41%; F1:   12.90; predicted:     4
#
# 	       other: precision:   25.95%; recall:   33.01%; F1:   29.06; predicted:   131
#
# 	      person: precision:   47.30%; recall:   33.65%; F1:   39.33; predicted:    74
#
# 	     product: precision:   14.29%; recall:    7.14%; F1:    9.52; predicted:    14
#
# 	  sportsteam: precision:   33.33%; recall:    3.23%; F1:    5.88; predicted:     3
#
# 	      tvshow: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     0
#
#
#
# Training model wiht parameters:
#
# Learning rate:  0.005
#
# Learning rated decay:  1.41421356237
#
# Dropout:  0.9
# Start training...
#
# -------------------- Epoch 1 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 79421 phrases; correct: 152.
#
# precision:  0.19%; recall:  3.39%; F1:  0.36
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 9709 phrases; correct: 25.
#
# precision:  0.26%; recall:  4.66%; F1:  0.49
#
# -------------------- Epoch 2 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 2852 phrases; correct: 946.
#
# precision:  33.17%; recall:  21.07%; F1:  25.77
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 226 phrases; correct: 83.
#
# precision:  36.73%; recall:  15.46%; F1:  21.76
#
# -------------------- Epoch 3 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 4701 phrases; correct: 2814.
#
# precision:  59.86%; recall:  62.69%; F1:  61.24
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 359 phrases; correct: 156.
#
# precision:  43.45%; recall:  29.05%; F1:  34.82
#
# -------------------- Epoch 4 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 4811 phrases; correct: 3779.
#
# precision:  78.55%; recall:  84.18%; F1:  81.27
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 405 phrases; correct: 197.
#
# precision:  48.64%; recall:  36.69%; F1:  41.83
#
# ...training finished.
# -------------------- Train set quality: --------------------
# processed 105778 tokens with 4489 phrases; found: 4683 phrases; correct: 4177.
#
# precision:  89.19%; recall:  93.05%; F1:  91.08
#
# 	     company: precision:   92.84%; recall:   96.73%; F1:   94.74; predicted:   670
#
# 	    facility: precision:   87.16%; recall:   90.76%; F1:   88.92; predicted:   327
#
# 	     geo-loc: precision:   92.99%; recall:   98.49%; F1:   95.66; predicted:  1055
#
# 	       movie: precision:   63.04%; recall:   42.65%; F1:   50.88; predicted:    46
#
# 	 musicartist: precision:   73.05%; recall:   88.79%; F1:   80.16; predicted:   282
#
# 	       other: precision:   89.67%; recall:   94.06%; F1:   91.81; predicted:   794
#
# 	      person: precision:   94.02%; recall:   97.52%; F1:   95.73; predicted:   919
#
# 	     product: precision:   87.38%; recall:   89.31%; F1:   88.34; predicted:   325
#
# 	  sportsteam: precision:   80.10%; recall:   74.19%; F1:   77.03; predicted:   201
#
# 	      tvshow: precision:   51.56%; recall:   56.90%; F1:   54.10; predicted:    64
#
# -------------------- Validation set quality: --------------------
# processed 12836 tokens with 537 phrases; found: 439 phrases; correct: 193.
#
# precision:  43.96%; recall:  35.94%; F1:  39.55
#
# 	     company: precision:   61.80%; recall:   52.88%; F1:   56.99; predicted:    89
#
# 	    facility: precision:   50.00%; recall:   41.18%; F1:   45.16; predicted:    28
#
# 	     geo-loc: precision:   66.67%; recall:   49.56%; F1:   56.85; predicted:    84
#
# 	       movie: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     0
#
# 	 musicartist: precision:    9.52%; recall:   14.29%; F1:   11.43; predicted:    42
#
# 	       other: precision:   30.00%; recall:   29.63%; F1:   29.81; predicted:    80
#
# 	      person: precision:   40.51%; recall:   28.57%; F1:   33.51; predicted:    79
#
# 	     product: precision:   20.00%; recall:   11.76%; F1:   14.81; predicted:    20
#
# 	  sportsteam: precision:   33.33%; recall:   20.00%; F1:   25.00; predicted:    12
#
# 	      tvshow: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     5
#
# -------------------- Test set quality: --------------------
# processed 13258 tokens with 604 phrases; found: 560 phrases; correct: 251.
#
# precision:  44.82%; recall:  41.56%; F1:  43.13
#
# 	     company: precision:   62.71%; recall:   44.05%; F1:   51.75; predicted:    59
#
# 	    facility: precision:   53.12%; recall:   36.17%; F1:   43.04; predicted:    32
#
# 	     geo-loc: precision:   68.09%; recall:   58.18%; F1:   62.75; predicted:   141
#
# 	       movie: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     0
#
# 	 musicartist: precision:    5.88%; recall:    7.41%; F1:    6.56; predicted:    34
#
# 	       other: precision:   37.86%; recall:   37.86%; F1:   37.86; predicted:   103
#
# 	      person: precision:   30.82%; recall:   47.12%; F1:   37.26; predicted:   159
#
# 	     product: precision:   25.00%; recall:   10.71%; F1:   15.00; predicted:    12
#
# 	  sportsteam: precision:   47.06%; recall:   25.81%; F1:   33.33; predicted:    17
#
# 	      tvshow: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     3
#
#
#
# Training model wiht parameters:
#
# Learning rate:  0.005
#
# Learning rated decay:  1.58113883008
#
# Dropout:  0.5
# Start training...
#
# -------------------- Epoch 1 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 75469 phrases; correct: 195.
#
# precision:  0.26%; recall:  4.34%; F1:  0.49
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 9034 phrases; correct: 19.
#
# precision:  0.21%; recall:  3.54%; F1:  0.40
#
# -------------------- Epoch 2 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 2175 phrases; correct: 329.
#
# precision:  15.13%; recall:  7.33%; F1:  9.87
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 194 phrases; correct: 41.
#
# precision:  21.13%; recall:  7.64%; F1:  11.22
#
# -------------------- Epoch 3 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 4314 phrases; correct: 1817.
#
# precision:  42.12%; recall:  40.48%; F1:  41.28
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 330 phrases; correct: 126.
#
# precision:  38.18%; recall:  23.46%; F1:  29.07
#
# -------------------- Epoch 4 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 4766 phrases; correct: 2757.
#
# precision:  57.85%; recall:  61.42%; F1:  59.58
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 385 phrases; correct: 166.
#
# precision:  43.12%; recall:  30.91%; F1:  36.01
#
# ...training finished.
# -------------------- Train set quality: --------------------
# processed 105778 tokens with 4489 phrases; found: 4757 phrases; correct: 3306.
#
# precision:  69.50%; recall:  73.65%; F1:  71.51
#
# 	     company: precision:   78.80%; recall:   85.54%; F1:   82.03; predicted:   698
#
# 	    facility: precision:   68.84%; recall:   73.89%; F1:   71.27; predicted:   337
#
# 	     geo-loc: precision:   74.38%; recall:   93.57%; F1:   82.88; predicted:  1253
#
# 	       movie: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     7
#
# 	 musicartist: precision:   38.36%; recall:   12.07%; F1:   18.36; predicted:    73
#
# 	       other: precision:   64.74%; recall:   78.34%; F1:   70.89; predicted:   916
#
# 	      person: precision:   69.67%; recall:   91.53%; F1:   79.12; predicted:  1164
#
# 	     product: precision:   51.16%; recall:   48.43%; F1:   49.76; predicted:   301
#
# 	  sportsteam: precision:   75.00%; recall:    2.76%; F1:    5.33; predicted:     8
#
# 	      tvshow: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     0
#
# -------------------- Validation set quality: --------------------
# processed 12836 tokens with 537 phrases; found: 418 phrases; correct: 185.
#
# precision:  44.26%; recall:  34.45%; F1:  38.74
#
# 	     company: precision:   61.80%; recall:   52.88%; F1:   56.99; predicted:    89
#
# 	    facility: precision:   54.55%; recall:   35.29%; F1:   42.86; predicted:    22
#
# 	     geo-loc: precision:   55.34%; recall:   50.44%; F1:   52.78; predicted:   103
#
# 	       movie: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     0
#
# 	 musicartist: precision:   25.00%; recall:    3.57%; F1:    6.25; predicted:     4
#
# 	       other: precision:   30.85%; recall:   35.80%; F1:   33.14; predicted:    94
#
# 	      person: precision:   34.18%; recall:   24.11%; F1:   28.27; predicted:    79
#
# 	     product: precision:   11.54%; recall:    8.82%; F1:   10.00; predicted:    26
#
# 	  sportsteam: precision:  100.00%; recall:    5.00%; F1:    9.52; predicted:     1
#
# 	      tvshow: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     0
#
# -------------------- Test set quality: --------------------
# processed 13258 tokens with 604 phrases; found: 529 phrases; correct: 230.
#
# precision:  43.48%; recall:  38.08%; F1:  40.60
#
# 	     company: precision:   57.14%; recall:   42.86%; F1:   48.98; predicted:    63
#
# 	    facility: precision:   47.50%; recall:   40.43%; F1:   43.68; predicted:    40
#
# 	     geo-loc: precision:   66.91%; recall:   56.36%; F1:   61.18; predicted:   139
#
# 	       movie: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     0
#
# 	 musicartist: precision:   25.00%; recall:    3.70%; F1:    6.45; predicted:     4
#
# 	       other: precision:   22.73%; recall:   33.98%; F1:   27.24; predicted:   154
#
# 	      person: precision:   55.70%; recall:   42.31%; F1:   48.09; predicted:    79
#
# 	     product: precision:    4.00%; recall:    7.14%; F1:    5.13; predicted:    50
#
# 	  sportsteam: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     0
#
# 	      tvshow: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     0
#
#
#
# Training model wiht parameters:
#
# Learning rate:  0.005
#
# Learning rated decay:  1.58113883008
#
# Dropout:  0.9
# Start training...
#
# -------------------- Epoch 1 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 76036 phrases; correct: 197.
#
# precision:  0.26%; recall:  4.39%; F1:  0.49
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 9302 phrases; correct: 19.
#
# precision:  0.20%; recall:  3.54%; F1:  0.39
#
# -------------------- Epoch 2 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 3950 phrases; correct: 878.
#
# precision:  22.23%; recall:  19.56%; F1:  20.81
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 291 phrases; correct: 75.
#
# precision:  25.77%; recall:  13.97%; F1:  18.12
#
# -------------------- Epoch 3 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 4549 phrases; correct: 2740.
#
# precision:  60.23%; recall:  61.04%; F1:  60.63
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 379 phrases; correct: 161.
#
# precision:  42.48%; recall:  29.98%; F1:  35.15
#
# -------------------- Epoch 4 of 4 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 4728 phrases; correct: 3743.
#
# precision:  79.17%; recall:  83.38%; F1:  81.22
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 387 phrases; correct: 185.
#
# precision:  47.80%; recall:  34.45%; F1:  40.04
#
# ...training finished.
# -------------------- Train set quality: --------------------
# processed 105778 tokens with 4489 phrases; found: 4684 phrases; correct: 4173.
#
# precision:  89.09%; recall:  92.96%; F1:  90.98
#
# 	     company: precision:   92.81%; recall:   96.42%; F1:   94.58; predicted:   668
#
# 	    facility: precision:   86.96%; recall:   95.54%; F1:   91.05; predicted:   345
#
# 	     geo-loc: precision:   94.28%; recall:   97.59%; F1:   95.91; predicted:  1031
#
# 	       movie: precision:   47.83%; recall:   64.71%; F1:   55.00; predicted:    92
#
# 	 musicartist: precision:   76.86%; recall:   75.86%; F1:   76.36; predicted:   229
#
# 	       other: precision:   88.61%; recall:   93.53%; F1:   91.00; predicted:   799
#
# 	      person: precision:   95.78%; recall:   97.40%; F1:   96.59; predicted:   901
#
# 	     product: precision:   75.81%; recall:   88.68%; F1:   81.74; predicted:   372
#
# 	  sportsteam: precision:   88.35%; recall:   83.87%; F1:   86.05; predicted:   206
#
# 	      tvshow: precision:   63.41%; recall:   44.83%; F1:   52.53; predicted:    41
#
# -------------------- Validation set quality: --------------------
# processed 12836 tokens with 537 phrases; found: 470 phrases; correct: 193.
#
# precision:  41.06%; recall:  35.94%; F1:  38.33
#
# 	     company: precision:   53.70%; recall:   55.77%; F1:   54.72; predicted:   108
#
# 	    facility: precision:   34.29%; recall:   35.29%; F1:   34.78; predicted:    35
#
# 	     geo-loc: precision:   68.24%; recall:   51.33%; F1:   58.59; predicted:    85
#
# 	       movie: precision:    5.26%; recall:   14.29%; F1:    7.69; predicted:    19
#
# 	 musicartist: precision:   25.00%; recall:   10.71%; F1:   15.00; predicted:    12
#
# 	       other: precision:   26.60%; recall:   30.86%; F1:   28.57; predicted:    94
#
# 	      person: precision:   45.45%; recall:   26.79%; F1:   33.71; predicted:    66
#
# 	     product: precision:    8.82%; recall:    8.82%; F1:    8.82; predicted:    34
#
# 	  sportsteam: precision:   21.43%; recall:   15.00%; F1:   17.65; predicted:    14
#
# 	      tvshow: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     3
#
# -------------------- Test set quality: --------------------
# processed 13258 tokens with 604 phrases; found: 494 phrases; correct: 240.
#
# precision:  48.58%; recall:  39.74%; F1:  43.72
#
# 	     company: precision:   62.30%; recall:   45.24%; F1:   52.41; predicted:    61
#
# 	    facility: precision:   40.82%; recall:   42.55%; F1:   41.67; predicted:    49
#
# 	     geo-loc: precision:   78.95%; recall:   54.55%; F1:   64.52; predicted:   114
#
# 	       movie: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:    22
#
# 	 musicartist: precision:   14.29%; recall:    7.41%; F1:    9.76; predicted:    14
#
# 	       other: precision:   34.95%; recall:   34.95%; F1:   34.95; predicted:   103
#
# 	      person: precision:   54.32%; recall:   42.31%; F1:   47.57; predicted:    81
#
# 	     product: precision:   11.11%; recall:   10.71%; F1:   10.91; predicted:    27
#
# 	  sportsteam: precision:   33.33%; recall:   22.58%; F1:   26.92; predicted:    21
#
# 	      tvshow: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:     2

# %% [markdown]
# ### Conclusions
#
# Could we say that our model is state of the art and the results are acceptable for the task? Definately, we can say so. Nowadays, Bi-LSTM is one of the state of the art approaches for solving NER problem and it outperforms other classical methods. Despite the fact that we used small training corpora (in comparison with usual sizes of corpora in Deep Learning), our results are quite good. In addition, in this task there are many possible named entities and for some of them we have only several dozens of trainig examples, which is definately small. However, the implemented model outperforms classical CRFs for this task. Even better results could be obtained by some combinations of several types of methods, e.g. see [this](https://arxiv.org/abs/1603.01354) paper if you are interested.

# %%
np.sqrt(2.5)
